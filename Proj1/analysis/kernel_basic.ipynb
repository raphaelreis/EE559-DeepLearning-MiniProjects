# %%
# %reload_ext autoreload
# %autoreload 1
import torch 
import sys
sys.path.append('..')
from torch import nn 
from torch.nn import functional as F
from torch import optim
from utils.loader import load,PairSetMNIST,Training_set,Test_set, Training_set_split,Validation_set
from torch.utils.data import Dataset, DataLoader
from models.Le_Net import  LeNet_sharing, train_Le_Net_Weight_Sharing
from models.Basic import train_simple, Net2C, Netcat
from utils.evaluate_basic import compute_metrics, validate_model, evaluate_model
from matplotlib import pyplot as plt
import torch.cuda as cuda 
from utils.plot import boxplot

# %%
# evaluate model on 10 trials for final results 

seeds = [3, 4, 452, 2345, 1234, 2134, 12345, 12377, 56765, 567776, 234, 1234, 1324543, 1234 , 345, 213456, 21345] # random seeds

train_results, test_losses, test_accuracies = evaluate_model(Net2C,train_simple, seeds, rotate=True, translate=True, swap_channel=True, GPU=True)

data = torch.stack([train_results[:,1,39], test_accuracies])  # group data for boxplot
boxplot(data, '2 Channel / nb hidden : 300')
# Out:
# Seed 0 | Test Loss: 0.0104 | Test Accuracy: 82.10%
# Seed 1 | Test Loss: 0.0105 | Test Accuracy: 86.20%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-987560b75bdd> in <module>
#       3 seeds = [3, 4, 452, 2345, 1234, 2134, 12345, 12377, 56765, 567776, 234, 1234, 1324543, 1234 , 345, 213456, 21345] # random seeds
#       4
# ----> 5 train_results, test_losses, test_accuracies = evaluate_model(Net2C,train_simple, seeds, rotate=True, translate=True, swap_channel=True, GPU=True)
#       6
#       7 data = torch.stack([train_results[:,1,39], test_accuracies])  # group data for boxplot
#
# c:\Users\vince\Documents\GitHub\DL_project\EE559-DeepLearning-MiniProjects\Proj1\utils\evaluate_basic.py in evaluate_model(net, training_function, seeds, mini_batch_size, optimizer, criterion, n_epochs, eta, lambda_l2, plot, rotate, translate, swap_channel, GPU)
# ...
